# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("voltage_analysis.csv")
df_train = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20/train.csv")

# %%
df
# Out:
#    pretty_formula filename  num_atoms  host_energy   Li_energy  Na_energy  \
# 0             CrO    gen_0        NaN          NaN         NaN        NaN
# 1           Cr2O3    gen_1        NaN          NaN         NaN        NaN
# 2       Li3CrFeO7   gen_10       12.0   -52.390564  -69.704687 -63.982442
# 3    LiFe(Ni2O3)2   gen_11       12.0   -56.852779  -62.723818 -61.209580
# 4       Li2Ni2HO4   gen_12        9.0   -32.535763  -43.504756 -40.512494
# ..            ...      ...        ...          ...         ...        ...
# 92         LiCoO2   gen_92        4.0   -17.215065  -22.720995 -21.452984
# 93         TiCrO4   gen_93        NaN          NaN         NaN        NaN
# 94        LiSbWO6   gen_94        9.0   -52.405220  -59.073722 -57.985293
# 95  Li2Mn3(FeO4)2   gen_95       15.0   -90.262246 -100.950241 -98.640707
# 96             O2   gen_96        NaN          NaN         NaN        NaN
#
#     host_energy_per_atom  Li_energy_per_atom  Na_energy_per_atom  Li_voltage  \
# 0                    NaN                 NaN                 NaN         NaN
# 1                    NaN                 NaN                 NaN         NaN
# 2              -5.821174           -5.808724           -5.331870    0.828174
# 3              -5.168434           -5.226985           -5.100798    0.927839
# 4              -4.647966           -4.833862           -4.501388    0.541296
# ..                   ...                 ...                 ...         ...
# 92             -5.738355           -5.680249           -5.363246    0.562729
# 93                   NaN                 NaN                 NaN         NaN
# 94             -6.550652           -6.563747           -6.442810    1.725302
# 95             -6.943250           -6.730016           -6.576047    0.400798
# 96                   NaN                 NaN                 NaN         NaN
#
#     Na_voltage                                     host_structure  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2    -0.155341  # generated using pymatgen\ndata_CrFeO7\n_symm...
# 3     0.337500  # generated using pymatgen\ndata_Fe(Ni2O3)2\n_...
# 4    -0.030935  # generated using pymatgen\ndata_Ni2HO4\n_symm...
# ..         ...                                                ...
# 92    0.218619  # generated using pymatgen\ndata_CoO2\n_symmet...
# 93         NaN                                                NaN
# 94    1.560773  # generated using pymatgen\ndata_SbWO6\n_symme...
# 95    0.169930  # generated using pymatgen\ndata_Mn3(FeO4)2\n_...
# 96         NaN                                                NaN
#
#                                          Li_structure  \
# 0                                                 NaN
# 1                                                 NaN
# 2   # generated using pymatgen\ndata_Li3CrFeO7\n_s...
# 3   # generated using pymatgen\ndata_LiFe(Ni2O3)2\...
# 4   # generated using pymatgen\ndata_Li2Ni2HO4\n_s...
# ..                                                ...
# 92  # generated using pymatgen\ndata_LiCoO2\n_symm...
# 93                                                NaN
# 94  # generated using pymatgen\ndata_LiSbWO6\n_sym...
# 95  # generated using pymatgen\ndata_Li2Mn3(FeO4)2...
# 96                                                NaN
#
#                                          Na_structure
# 0                                                 NaN
# 1                                                 NaN
# 2   # generated using pymatgen\ndata_Na3CrFeO7\n_s...
# 3   # generated using pymatgen\ndata_NaFe(Ni2O3)2\...
# 4   # generated using pymatgen\ndata_Na2Ni2HO4\n_s...
# ..                                                ...
# 92  # generated using pymatgen\ndata_NaCoO2\n_symm...
# 93                                                NaN
# 94  # generated using pymatgen\ndata_NaSbWO6\n_sym...
# 95  # generated using pymatgen\ndata_Na2Mn3(FeO4)2...
# 96                                                NaN
#
# [97 rows x 14 columns]

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage'],label="li voltage",bins=50,range=(-8,8))
plt.hist(df['Na_voltage'],label="na voltage",bins=50,range=(-8,8),alpha=0.6)
plt.xlim(-8,8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage']-df['Na_voltage'],label="Li voltage - Na voltage",bins=30,density=True)
plt.hist(df_train['Li_voltage']-df_train['Na_voltage'],label="Li voltage - Na voltage, train",bins=50,alpha=0.6,density=True)
plt.xlim(-2,3)
plt.legend()
plt.show()
