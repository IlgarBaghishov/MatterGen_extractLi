# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("voltage_analysis.csv")
df_train = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20/train.csv")

# %%
df
# Out:
#    pretty_formula filename  num_atoms  host_energy   Li_energy  Na_energy  \
# 0      Li3Co3CuO7    gen_0       14.0   -59.504787  -75.623346 -72.150304
# 1      Li2Mn2FeO5    gen_1       10.0   -55.581161  -65.877452 -63.349148
# 2         Li5FeO4   gen_10       20.0   -48.538475 -106.173100 -92.265731
# 3         Li2CrO3   gen_11       12.0   -51.422628  -75.175676 -69.767959
# 4       LiTi2NiO6   gen_12       10.0   -65.208851  -72.002512 -70.549522
# ..            ...      ...        ...          ...         ...        ...
# 95          LiVSO   gen_95        4.0   -19.733948  -23.788099 -22.941937
# 96    Li2Ni(IO3)2   gen_96       11.0   -39.129494  -48.617426 -46.625215
# 97       LiMn2OF4   gen_97       16.0   -84.627877  -96.952913 -95.077591
# 98       LiNbMoO6   gen_98        9.0   -61.386933  -67.492888 -66.816185
# 99       Li3CrO3F   gen_99        8.0   -28.584505  -46.874522 -42.993524
#
#     host_energy_per_atom  Li_energy_per_atom  Na_energy_per_atom  Li_voltage  \
# 0              -5.409526           -5.401668           -5.153593    0.429653
# 1              -6.947645           -6.587745           -6.334915    0.204945
# 2              -4.853847           -5.308655           -4.613287    0.820262
# 3              -6.427829           -6.264640           -5.813997    0.995062
# 4              -7.245428           -7.200251           -7.054952    1.850461
# ..                   ...                 ...                 ...         ...
# 95             -6.577983           -5.947025           -5.735484   -0.889050
# 96             -4.347722           -4.419766           -4.238656   -0.199234
# 97             -6.044848           -6.059557           -5.942349    1.219318
# 98             -7.673367           -7.499210           -7.424021    1.162756
# 99             -5.716901           -5.859315           -5.374190    1.153472
#
#     Na_voltage                                     host_structure  \
# 0     0.195872  # generated using pymatgen\ndata_Co3CuO7\n_sym...
# 1    -0.135306  # generated using pymatgen\ndata_Mn2FeO5\n_sym...
# 2     0.353426  # generated using pymatgen\ndata_FeO4\n_symmet...
# 3     0.567033  # generated using pymatgen\ndata_CrO3\n_symmet...
# 4     1.321371  # generated using pymatgen\ndata_Ti2NiO6\n_sym...
# ..         ...                                                ...
# 95   -0.811311  # generated using pymatgen\ndata_VSO\n_symmetr...
# 96   -0.271439  # generated using pymatgen\ndata_Ni(IO3)2\n_sy...
# 97    1.205557  # generated using pymatgen\ndata_Mn2OF4\n_symm...
# 98    1.409952  # generated using pymatgen\ndata_NbMoO6\n_symm...
# 99    0.783706  # generated using pymatgen\ndata_CrO3F\n_symme...
#
#                                          Li_structure  \
# 0   # generated using pymatgen\ndata_Li3Co3CuO7\n_...
# 1   # generated using pymatgen\ndata_Li2Mn2FeO5\n_...
# 2   # generated using pymatgen\ndata_Li5FeO4\n_sym...
# 3   # generated using pymatgen\ndata_Li2CrO3\n_sym...
# 4   # generated using pymatgen\ndata_LiTi2NiO6\n_s...
# ..                                                ...
# 95  # generated using pymatgen\ndata_LiVSO\n_symme...
# 96  # generated using pymatgen\ndata_Li2Ni(IO3)2\n...
# 97  # generated using pymatgen\ndata_LiMn2OF4\n_sy...
# 98  # generated using pymatgen\ndata_LiNbMoO6\n_sy...
# 99  # generated using pymatgen\ndata_Li3CrO3F\n_sy...
#
#                                          Na_structure
# 0   # generated using pymatgen\ndata_Na3Co3CuO7\n_...
# 1   # generated using pymatgen\ndata_Na2Mn2FeO5\n_...
# 2   # generated using pymatgen\ndata_Na5FeO4\n_sym...
# 3   # generated using pymatgen\ndata_Na2CrO3\n_sym...
# 4   # generated using pymatgen\ndata_NaTi2NiO6\n_s...
# ..                                                ...
# 95  # generated using pymatgen\ndata_NaVSO\n_symme...
# 96  # generated using pymatgen\ndata_Na2Ni(IO3)2\n...
# 97  # generated using pymatgen\ndata_NaMn2OF4\n_sy...
# 98  # generated using pymatgen\ndata_NaNbMoO6\n_sy...
# 99  # generated using pymatgen\ndata_Na3CrO3F\n_sy...
#
# [100 rows x 14 columns]

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage'],label="li voltage",bins=50,range=(-8,8))
plt.hist(df['Na_voltage'],label="na voltage",bins=50,range=(-8,8),alpha=0.6)
plt.xlim(-8,8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage']-df['Na_voltage'],label="Li voltage - Na voltage",bins=50,density=True)
plt.hist(df_train['Li_voltage']-df_train['Na_voltage'],label="Li voltage - Na voltage, train",bins=50,alpha=0.6,density=True)
plt.xlim(-2,3)
plt.legend()
plt.show()
