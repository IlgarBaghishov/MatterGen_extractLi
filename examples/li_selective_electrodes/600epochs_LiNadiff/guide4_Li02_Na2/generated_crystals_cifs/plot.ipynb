# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("voltage_analysis.csv")
df_train = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20/train.csv")

# %%
df
# Out:
#       pretty_formula filename  num_atoms  host_energy  Li_energy  Na_energy  \
# 0           Co3Ni3O8    gen_0        NaN          NaN        NaN        NaN
# 1           Cr2Ni2O5    gen_1        NaN          NaN        NaN        NaN
# 2              Cr5O6   gen_10        NaN          NaN        NaN        NaN
# 3                NiO   gen_11        NaN          NaN        NaN        NaN
# 4           Cr2FeO4F   gen_12        NaN          NaN        NaN        NaN
# ..               ...      ...        ...          ...        ...        ...
# 95             VCrO3   gen_95        NaN          NaN        NaN        NaN
# 96       LiCr(SbO4)2   gen_96       12.0   -67.172066 -73.640892 -72.189393
# 97            CrNiO3   gen_97        NaN          NaN        NaN        NaN
# 98  LiFe3CoNi3(O4F)2   gen_98       18.0   -93.489294 -98.912202 -97.885237
# 99               NiO   gen_99        NaN          NaN        NaN        NaN
#
#     host_energy_per_atom  Li_energy_per_atom  Na_energy_per_atom  Li_voltage  \
# 0                    NaN                 NaN                 NaN         NaN
# 1                    NaN                 NaN                 NaN         NaN
# 2                    NaN                 NaN                 NaN         NaN
# 3                    NaN                 NaN                 NaN         NaN
# 4                    NaN                 NaN                 NaN         NaN
# ..                   ...                 ...                 ...         ...
# 95                   NaN                 NaN                 NaN         NaN
# 96             -6.106551           -6.136741           -6.015783    1.525626
# 97                   NaN                 NaN                 NaN         NaN
# 98             -5.499370           -5.495122           -5.438069    0.479708
# 99                   NaN                 NaN                 NaN         NaN
#
#     Na_voltage                                     host_structure  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# ..         ...                                                ...
# 95         NaN                                                NaN
# 96    0.998027  # generated using pymatgen\ndata_Cr(SbO4)2\n_s...
# 97         NaN                                                NaN
# 98    0.376644  # generated using pymatgen\ndata_Fe3CoNi3(O4F)...
# 99         NaN                                                NaN
#
#                                          Li_structure  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  # generated using pymatgen\ndata_LiCr(SbO4)2\n...
# 97                                                NaN
# 98  # generated using pymatgen\ndata_LiFe3CoNi3(O4...
# 99                                                NaN
#
#                                          Na_structure
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  # generated using pymatgen\ndata_NaCr(SbO4)2\n...
# 97                                                NaN
# 98  # generated using pymatgen\ndata_NaFe3CoNi3(O4...
# 99                                                NaN
#
# [100 rows x 14 columns]

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage'],label="li voltage",bins=50,range=(-8,8))
plt.hist(df['Na_voltage'],label="na voltage",bins=50,range=(-8,8),alpha=0.6)
plt.xlim(-8,8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage']-df['Na_voltage'],label="Li voltage - Na voltage",bins=50,density=True)
plt.hist(df_train['Li_voltage']-df_train['Na_voltage'],label="Li voltage - Na voltage, train",bins=50,alpha=0.6,density=True)
plt.xlim(-2,3)
plt.legend()
plt.show()
