# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("voltage_analysis.csv")
df_train = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20/train.csv")

# %%
df
# Out:
#    pretty_formula filename  num_atoms  host_energy   Li_energy   Na_energy  \
# 0        Li2Mn2O5    gen_0       18.0   -90.106106 -115.578972 -109.389839
# 1    LiFeCoCuBiO6    gen_1       11.0   -57.341170  -62.320553  -61.093908
# 2       Li3V3NiO9   gen_10       16.0   -87.920470 -105.205741 -101.584534
# 3        LiV2ZnO6   gen_11       10.0   -60.211945  -65.500205  -64.306705
# 4        Li(NiO)2   gen_12        5.0   -19.230022  -21.164283  -19.958430
# ..            ...      ...        ...          ...         ...         ...
# 95    LiV3Zn3O10F   gen_95       18.0  -105.174400 -110.238529 -109.095335
# 96       Li6Mn3O7   gen_96       16.0   -65.113757  -96.324965  -87.653429
# 97       LiZnCrO3   gen_97       12.0   -61.153391  -72.179180  -69.187203
# 98     Li4Cu3GeO8   gen_98       16.0   -60.526620  -84.234221  -79.633564
# 99     Li3Fe4CoO8   gen_99       16.0   -80.960882  -96.894624  -91.475651
#
#     host_energy_per_atom  Li_energy_per_atom  Na_energy_per_atom  Li_voltage  \
# 0              -6.436150           -6.421054           -6.077213    1.425017
# 1              -5.734117           -5.665505           -5.553992    0.036183
# 2              -6.763113           -6.575359           -6.349033    0.818557
# 3              -6.690216           -6.550020           -6.430671    0.345060
# 4              -4.807506           -4.232857           -3.991686   -3.008940
# ..                   ...                 ...                 ...         ...
# 95             -6.186729           -6.124363           -6.060852    0.120928
# 96             -6.511376           -6.020310           -5.478339    0.258668
# 97             -6.115339           -6.014932           -5.765600    0.569694
# 98             -5.043885           -5.264639           -4.977098    0.983700
# 99             -6.227760           -6.055914           -5.717228    0.368047
#
#     Na_voltage                                     host_structure  \
# 0     0.801633  # generated using pymatgen\ndata_Mn2O5\n_symme...
# 1    -0.266562  # generated using pymatgen\ndata_FeCoCuBiO6\n_...
# 2     0.535388  # generated using pymatgen\ndata_V3NiO9\n_symm...
# 3     0.075461  # generated using pymatgen\ndata_V2ZnO6\n_symm...
# 4    -3.290892  # generated using pymatgen\ndata_NiO\n_symmetr...
# ..         ...                                                ...
# 95   -0.098365  # generated using pymatgen\ndata_V3Zn3O10F\n_s...
# 96   -0.262688  # generated using pymatgen\ndata_Mn3O7\n_symme...
# 97   -0.002394  # generated using pymatgen\ndata_ZnCrO3\n_symm...
# 98    0.757436  # generated using pymatgen\ndata_Cu3GeO8\n_sym...
# 99   -0.514377  # generated using pymatgen\ndata_Fe4CoO8\n_sym...
#
#                                          Li_structure  \
# 0   # generated using pymatgen\ndata_Li2Mn2O5\n_sy...
# 1   # generated using pymatgen\ndata_LiFeCoCuBiO6\...
# 2   # generated using pymatgen\ndata_Li3V3NiO9\n_s...
# 3   # generated using pymatgen\ndata_LiV2ZnO6\n_sy...
# 4   # generated using pymatgen\ndata_Li(NiO)2\n_sy...
# ..                                                ...
# 95  # generated using pymatgen\ndata_LiV3Zn3O10F\n...
# 96  # generated using pymatgen\ndata_Li6Mn3O7\n_sy...
# 97  # generated using pymatgen\ndata_LiZnCrO3\n_sy...
# 98  # generated using pymatgen\ndata_Li4Cu3GeO8\n_...
# 99  # generated using pymatgen\ndata_Li3Fe4CoO8\n_...
#
#                                          Na_structure
# 0   # generated using pymatgen\ndata_Na2Mn2O5\n_sy...
# 1   # generated using pymatgen\ndata_NaFeCoCuBiO6\...
# 2   # generated using pymatgen\ndata_Na3V3NiO9\n_s...
# 3   # generated using pymatgen\ndata_NaV2ZnO6\n_sy...
# 4   # generated using pymatgen\ndata_Na(NiO)2\n_sy...
# ..                                                ...
# 95  # generated using pymatgen\ndata_NaV3Zn3O10F\n...
# 96  # generated using pymatgen\ndata_Na6Mn3O7\n_sy...
# 97  # generated using pymatgen\ndata_NaZnCrO3\n_sy...
# 98  # generated using pymatgen\ndata_Na4Cu3GeO8\n_...
# 99  # generated using pymatgen\ndata_Na3Fe4CoO8\n_...
#
# [100 rows x 14 columns]

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage'],label="li voltage",bins=50,range=(-8,8))
plt.hist(df['Na_voltage'],label="na voltage",bins=50,range=(-8,8),alpha=0.6)
plt.xlim(-8,8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage']-df['Na_voltage'],label="Li voltage - Na voltage",bins=50,density=True)
plt.hist(df_train['Li_voltage']-df_train['Na_voltage'],label="Li voltage - Na voltage, train",bins=50,alpha=0.6,density=True)
plt.xlim(-2,3)
plt.legend()
plt.show()
