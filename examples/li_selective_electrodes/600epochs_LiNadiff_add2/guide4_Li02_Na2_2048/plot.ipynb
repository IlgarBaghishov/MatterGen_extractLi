# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("generated_crystals_cifs/voltage_analysis.csv")
df_old100 = pd.read_csv("../../600epochs_LiNadiff/guide4_Li02_Na2/generated_crystals_cifs/voltage_analysis.csv")
df_old2048 = pd.read_csv("../../600epochs_LiNadiff/guide4_Li02_Na2_2048/generated_crystals_cifs/voltage_analysis.csv")
df_diff_add1_guide2 = pd.read_csv("../../600epochs_LiNadiff_add1/guide2_Li02_Na2_2048/generated_crystals_cifs/voltage_analysis.csv")
df_diff_add1_guide4 = pd.read_csv("../../600epochs_LiNadiff_add1/guide4_Li02_Na2_2048/generated_crystals_cifs/voltage_analysis.csv")

df_train = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20/train.csv")
df_train_diff_add1 = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20_diff_add1/train.csv")
df_train_diff_add2 = pd.read_csv("/home/ilgar/MatterGen_extractLi/datasets/li_data_20_diff_add2/train.csv")

# %%
df
# Out:
#      pretty_formula  filename  num_atoms  host_energy  Li_energy  Na_energy  \
# 0            CrPdO3     gen_0        NaN          NaN        NaN        NaN
# 1        LiNiPdRhO6     gen_1       10.0   -49.451279 -54.513898 -52.333055
# 2            LiCrNO    gen_10        4.0   -21.084257 -26.213459 -23.782250
# 3            LiCrNO   gen_100        4.0   -21.084254 -26.213654 -25.026025
# 4            LiCrNO  gen_1000        4.0   -20.843281 -25.780874 -23.244467
# ...             ...       ...        ...          ...        ...        ...
# 2043         LiCrNO   gen_995        4.0   -21.084159 -26.213455 -23.782355
# 2044         LiCrNO   gen_996        4.0   -21.084232 -26.213408 -25.025753
# 2045         LiCrN2   gen_997        4.0   -24.993782 -29.631778 -28.082952
# 2046         LiCrO2   gen_998        8.0   -44.369987 -51.064977 -51.335340
# 2047        LiCr4O7   gen_999       12.0   -82.995984 -87.626585 -85.431633
#
#       host_energy_per_atom  Li_energy_per_atom  Na_energy_per_atom  \
# 0                      NaN                 NaN                 NaN
# 1                -5.494587           -5.451390           -5.233305
# 2                -7.028086           -6.553365           -5.945562
# 3                -7.028085           -6.553413           -6.256506
# 4                -6.947760           -6.445218           -5.811117
# ...                    ...                 ...                 ...
# 2043             -7.028053           -6.553364           -5.945589
# 2044             -7.028077           -6.553352           -6.256438
# 2045             -8.331261           -7.407945           -7.020738
# 2046             -7.394998           -6.383122           -6.416918
# 2047             -7.545089           -7.302215           -7.119303
#
#       Li_voltage  Na_voltage  \
# 0            NaN         NaN
# 1       0.119419   -1.137524
# 2       0.186003   -1.321307
# 3       0.186200   -0.077529
# 4      -0.005608   -1.618115
# ...          ...         ...
# 2043    0.186096   -1.321105
# 2044    0.185976   -0.077779
# 2045   -0.305204   -0.930130
# 2046   -1.595705   -0.536623
# 2047   -0.312599   -1.583651
#
#                                          host_structure  \
# 0                                                   NaN
# 1     # generated using pymatgen\ndata_NiPdRhO6\n_sy...
# 2     # generated using pymatgen\ndata_CrNO\n_symmet...
# 3     # generated using pymatgen\ndata_CrNO\n_symmet...
# 4     # generated using pymatgen\ndata_CrNO\n_symmet...
# ...                                                 ...
# 2043  # generated using pymatgen\ndata_CrNO\n_symmet...
# 2044  # generated using pymatgen\ndata_CrNO\n_symmet...
# 2045  # generated using pymatgen\ndata_CrN2\n_symmet...
# 2046  # generated using pymatgen\ndata_CrO2\n_symmet...
# 2047  # generated using pymatgen\ndata_Cr4O7\n_symme...
#
#                                            Li_structure  \
# 0                                                   NaN
# 1     # generated using pymatgen\ndata_LiNiPdRhO6\n_...
# 2     # generated using pymatgen\ndata_LiCrNO\n_symm...
# 3     # generated using pymatgen\ndata_LiCrNO\n_symm...
# 4     # generated using pymatgen\ndata_LiCrNO\n_symm...
# ...                                                 ...
# 2043  # generated using pymatgen\ndata_LiCrNO\n_symm...
# 2044  # generated using pymatgen\ndata_LiCrNO\n_symm...
# 2045  # generated using pymatgen\ndata_LiCrN2\n_symm...
# 2046  # generated using pymatgen\ndata_LiCrO2\n_symm...
# 2047  # generated using pymatgen\ndata_LiCr4O7\n_sym...
#
#                                            Na_structure
# 0                                                   NaN
# 1     # generated using pymatgen\ndata_NaNiPdRhO6\n_...
# 2     # generated using pymatgen\ndata_NaCrNO\n_symm...
# 3     # generated using pymatgen\ndata_NaCrNO\n_symm...
# 4     # generated using pymatgen\ndata_NaCrNO\n_symm...
# ...                                                 ...
# 2043  # generated using pymatgen\ndata_NaCrNO\n_symm...
# 2044  # generated using pymatgen\ndata_NaCrNO\n_symm...
# 2045  # generated using pymatgen\ndata_NaCrN2\n_symm...
# 2046  # generated using pymatgen\ndata_NaCrO2\n_symm...
# 2047  # generated using pymatgen\ndata_NaCr4O7\n_sym...
#
# [2048 rows x 14 columns]

# %%
plt.figure(figsize=(6,6))
plt.hist(df['Li_voltage'],label="li voltage",bins=50,range=(-8,8))
plt.hist(df['Na_voltage'],label="na voltage",bins=50,range=(-8,8),alpha=0.6)
plt.xlim(-8,8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.hist(df_train['Li_voltage']-df_train['Na_voltage'],label="Li voltage - Na voltage, train",bins=50,density=True)
plt.hist(df_old2048['Li_voltage']-df_old2048['Na_voltage'],label="Li voltage - Na voltage, old generated",bins=50,alpha=0.6,density=True)
plt.hist(df_diff_add1_guide4['Li_voltage']-df_diff_add1_guide4['Na_voltage'],label="Li voltage - Na voltage, diff add1",bins=50,alpha=0.6,density=True)
plt.hist(df['Li_voltage']-df['Na_voltage'],label="Li voltage - Na voltage, new generated",bins=50,alpha=0.6,density=True)
plt.xlim(-2,3)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_train['Li_voltage'],df_train['Na_voltage'],s=3,label="train data",c='k')
plt.scatter(df_old2048['Li_voltage'],df_old2048['Na_voltage'],s=3,label="old generated data")
plt.scatter(df['Li_voltage'],df['Na_voltage'],s=3,label="generated data", alpha=0.4)
plt.xlim(-6,6)
plt.ylim(-6,6)
plt.xlabel("Li voltage (V)")
plt.ylabel("Na voltage (V)")
plt.legend()
plt.show()

# %%
df_to_add = df[['pretty_formula', 'num_atoms', 'host_energy_per_atom', 'Li_energy_per_atom', 'Na_energy_per_atom', 'Li_voltage', 'Na_voltage', 'Li_structure']]
df_to_add.columns = ['pretty_formula', 'num_atoms', 'host_energy_per_atom', 'Li_energy_per_atom', 'Na_energy_per_atom', 'Li_voltage', 'Na_voltage', 'cif']
df_to_add['Na_voltage'] = df_to_add['Li_voltage'] - df_to_add['Na_voltage']
# Out:
# /tmp/ipykernel_1996265/4151272627.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_to_add['Na_voltage'] = df_to_add['Li_voltage'] - df_to_add['Na_voltage']

# %%
df_old_to_add = df_old[['pretty_formula', 'num_atoms', 'host_energy_per_atom', 'Li_energy_per_atom', 'Na_energy_per_atom', 'Li_voltage', 'Na_voltage', 'Li_structure']]
df_old_to_add.columns = ['pretty_formula', 'num_atoms', 'host_energy_per_atom', 'Li_energy_per_atom', 'Na_energy_per_atom', 'Li_voltage', 'Na_voltage', 'cif']
df_old_to_add['Na_voltage'] = df_old_to_add['Li_voltage'] - df_old_to_add['Na_voltage']
# Out:
# /tmp/ipykernel_1996265/1798932268.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_old_to_add['Na_voltage'] = df_old_to_add['Li_voltage'] - df_old_to_add['Na_voltage']

# %%
df_merged = pd.concat([df_train,df_to_add,df_old_to_add],ignore_index=True)

# %%
# remove nan rows except if Nan is only in 'material_id' column
df_merged_cleaned = df_merged.dropna(subset=['Li_voltage', 'Na_voltage', 'host_energy_per_atom', 'Li_energy_per_atom', 'Na_energy_per_atom'])

# %%
df_merged_cleaned.to_csv("train_extended_cleaned.csv",index=False)

# %%
df_merged_cleaned
# Out:
#         pretty_formula material_id  num_atoms  host_energy_per_atom  \
# 0           Rb2LiBi2O5   mp-975106       10.0             -5.001463
# 1              LiVCl2O  mp-1216404        5.0             -5.365562
# 2        LiScTl(MoO4)2    mp-19450       13.0             -7.246476
# 3           Li4Cr3FeO8   mp-756058       16.0             -6.821576
# 4        Ba4Li(Co2O5)2  mp-1076439       19.0             -6.059365
# ...                ...         ...        ...                   ...
# 3862         LiCr2NiO6         NaN       10.0             -6.418833
# 3864         LiAlCr5O8         NaN       15.0             -7.741191
# 3866      LiCr2(NiO2)2         NaN        9.0             -6.042746
# 3868       LiCr(SbO4)2         NaN       12.0             -6.106551
# 3870  LiFe3CoNi3(O4F)2         NaN       18.0             -5.499370
#
#       Li_energy_per_atom  Na_energy_per_atom  Li_voltage  Na_voltage  \
# 0              -4.840352           -4.775824   -1.552852   -1.274225
# 1              -5.168905           -4.801249   -0.560927   -1.475303
# 2              -6.905751           -6.844393   -2.126157   -1.999905
# 3              -6.671563           -6.509723    0.678274    0.307453
# 4              -5.934136           -5.872205   -1.263181   -1.515970
# ...                  ...                 ...         ...         ...
# 3862           -6.344823           -6.205362    0.735528    0.470709
# 3864           -7.435713           -7.356704   -1.784173    0.261232
# 3866           -5.595628           -5.691299   -2.924517   -1.784939
# 3868           -6.136741           -6.015783    1.525626    0.527599
# 3870           -5.495122           -5.438069    0.479708    0.103065
#
#                                                     cif
# 0     # generated using pymatgen\ndata_Rb2LiBi2O5\n_...
# 1     # generated using pymatgen\ndata_LiVCl2O\n_sym...
# 2     # generated using pymatgen\ndata_LiScTl(MoO4)2...
# 3     # generated using pymatgen\ndata_Li4Cr3FeO8\n_...
# 4     # generated using pymatgen\ndata_Ba4Li(Co2O5)2...
# ...                                                 ...
# 3862  # generated using pymatgen\ndata_LiCr2NiO6\n_s...
# 3864  # generated using pymatgen\ndata_LiAlCr5O8\n_s...
# 3866  # generated using pymatgen\ndata_LiCr2(NiO2)2\...
# 3868  # generated using pymatgen\ndata_LiCr(SbO4)2\n...
# 3870  # generated using pymatgen\ndata_LiFe3CoNi3(O4...
#
# [2752 rows x 9 columns]
